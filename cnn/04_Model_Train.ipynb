# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import image

from os import listdir
from os.path import isfile, join

import tensorflow as tf

from tensorflow.keras import callbacks, Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, GlobalAveragePooling2D
from keras.applications import MobileNet
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import average_precision_score

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
spec_dir = '../data/image_data/'
sample_dir = '../data/image_data/Polistes_dominula/'

paths_sample_plot = [join(sample_dir, f) for f in listdir(sample_dir) if isfile(join(sample_dir, f))]

# %% [markdown]
# - (b) View Batch

# %%
plt.figure(figsize=(6,6))

plt.subplot(221)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(222)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(223)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(224)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]));

# %% [markdown]
# Define Batch size

# %%
batch_size = 16

# %% [markdown]
# ## B - <a name="generateurs"></a> Data Generators

# %%
train_data_generator = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                   )

test_data_generator  = ImageDataGenerator(rescale = 1./255)
data_generator  = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# - (d) Implement ```training_data```, ```valid_data``` splits

# %%
training_data  = train_data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "training", 
                                                   batch_size = batch_size)

validation_data  = train_data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "validation", 
                                                   batch_size = batch_size)

#test_data  = test_data_generator.flow_from_directory(directory = spec_dir,
#                                                   target_size = (224, 224),
#                                                   class_mode = 'binary',
#                                                   batch_size = batch_size)
# Out:
# Found 1951 images belonging to 16 classes.
# Found 479 images belonging to 16 classes.

# %% [markdown]
# # II - <a name="classif"></a> Classification

# %%
# Model MobileNet
base_model = MobileNet(weights='imagenet', include_top=False)

# Freezer les couches
for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model) # Ajout du modèl
model.add(GlobalAveragePooling2D())
model.add(Dropout(rate=0.2))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(16, activation='softmax'))
# Out:
# C:\Users\dgnhk\AppData\Local\Temp\ipykernel_7324\3460812574.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(weights='imagenet', include_top=False)

# %%
early_stopping = callbacks.EarlyStopping(monitor = 'val_loss',
                                         patience = 4,
                                         mode = 'min',
                                         restore_best_weights = True)

lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                                        patience=3,
                                         factor=0.5,
                                         verbose=2,
                                         mode='min',
                                         min_lr = 1e-10)

# %%
optimizer = Adam(learning_rate=0.0001)

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import average_precision_score
from sklearn.preprocessing import label_binarize

class AveragePrecisionCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_generator, num_classes=16):
        super().__init__()
        self.val_generator = val_generator
        self.num_classes = num_classes

    def on_epoch_end(self, epoch, logs=None):
        y_true = []
        y_pred = []

        for i in range(len(self.val_generator)):
            x_batch, y_batch = self.val_generator[i]  # y_batch: shape (batch_size,)
            preds = self.model.predict(x_batch, verbose=0)  # preds: shape (batch_size, num_classes)

            y_true.extend(y_batch)
            y_pred.extend(preds)

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)

        # One-hot encode y_true to match y_pred's shape
        y_true_onehot = label_binarize(y_true, classes=range(self.num_classes))

        # Compute average precision per class
        aps = []
        for i in range(self.num_classes):
            ap = average_precision_score(y_true_onehot[:, i], y_pred[:, i])
            aps.append(ap)

        macro_ap = np.mean(aps)
        print(f"\nEpoch {epoch + 1}: val_average_precision = {macro_ap:.4f}")
        logs = logs or {}
        logs['val_average_precision'] = macro_ap

# %%
ap_callback = AveragePrecisionCallback(val_generator=validation_data)

# %%
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(training_data, validation_data=validation_data, epochs=30, 
                    callbacks=[ap_callback,lr_plateau])
# Out:
# Epoch 1/30
# c:\Users\dgnhk\anaconda3\envs\yevhenii\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.0665 - loss: 3.0183
# Epoch 1: val_average_precision = 0.1189
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 108s 838ms/step - accuracy: 0.0666 - loss: 3.0172 - val_accuracy: 0.1148 - val_loss: 2.7246 - val_average_precision: 0.1189 - learning_rate: 1.0000e-04
# Epoch 2/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.0891 - loss: 2.7520
# Epoch 2: val_average_precision = 0.1709
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 92s 745ms/step - accuracy: 0.0892 - loss: 2.7518 - val_accuracy: 0.1399 - val_loss: 2.6519 - val_average_precision: 0.1709 - learning_rate: 1.0000e-04
# Epoch 3/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.1306 - loss: 2.6454
# Epoch 3: val_average_precision = 0.2196
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 95s 762ms/step - accuracy: 0.1307 - loss: 2.6453 - val_accuracy: 0.1670 - val_loss: 2.5265 - val_average_precision: 0.2196 - learning_rate: 1.0000e-04
# Epoch 4/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.1703 - loss: 2.5491
# Epoch 4: val_average_precision = 0.2906
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 68s 546ms/step - accuracy: 0.1704 - loss: 2.5487 - val_accuracy: 0.2568 - val_loss: 2.3676 - val_average_precision: 0.2906 - learning_rate: 1.0000e-04
# Epoch 5/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.2636 - loss: 2.3793
# Epoch 5: val_average_precision = 0.3480
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - accuracy: 0.2636 - loss: 2.3789 - val_accuracy: 0.3132 - val_loss: 2.2219 - val_average_precision: 0.3480 - learning_rate: 1.0000e-04
# Epoch 6/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.3022 - loss: 2.2023
# Epoch 6: val_average_precision = 0.4003
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 31s 250ms/step - accuracy: 0.3023 - loss: 2.2023 - val_accuracy: 0.3820 - val_loss: 2.0598 - val_average_precision: 0.4003 - learning_rate: 1.0000e-04
# Epoch 7/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.3702 - loss: 2.0180
# Epoch 7: val_average_precision = 0.4473
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 46s 365ms/step - accuracy: 0.3701 - loss: 2.0183 - val_accuracy: 0.4405 - val_loss: 1.9431 - val_average_precision: 0.4473 - learning_rate: 1.0000e-04
# Epoch 8/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3847 - loss: 1.9512
# Epoch 8: val_average_precision = 0.4783
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 27s 214ms/step - accuracy: 0.3848 - loss: 1.9508 - val_accuracy: 0.4551 - val_loss: 1.8436 - val_average_precision: 0.4783 - learning_rate: 1.0000e-04
# Epoch 9/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4337 - loss: 1.8566
# Epoch 9: val_average_precision = 0.5106
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 24s 193ms/step - accuracy: 0.4337 - loss: 1.8565 - val_accuracy: 0.4739 - val_loss: 1.7737 - val_average_precision: 0.5106 - learning_rate: 1.0000e-04
# Epoch 10/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4394 - loss: 1.7950
# Epoch 10: val_average_precision = 0.5413
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 25s 201ms/step - accuracy: 0.4397 - loss: 1.7945 - val_accuracy: 0.5052 - val_loss: 1.6851 - val_average_precision: 0.5413 - learning_rate: 1.0000e-04
# Epoch 11/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5079 - loss: 1.5727
# Epoch 11: val_average_precision = 0.5569
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - accuracy: 0.5077 - loss: 1.5732 - val_accuracy: 0.5177 - val_loss: 1.6356 - val_average_precision: 0.5569 - learning_rate: 1.0000e-04
# Epoch 12/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5038 - loss: 1.5332
# Epoch 12: val_average_precision = 0.5667
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 26s 211ms/step - accuracy: 0.5038 - loss: 1.5334 - val_accuracy: 0.4969 - val_loss: 1.5976 - val_average_precision: 0.5667 - learning_rate: 1.0000e-04
# Epoch 13/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5302 - loss: 1.4660
# Epoch 13: val_average_precision = 0.5786
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 29s 237ms/step - accuracy: 0.5303 - loss: 1.4659 - val_accuracy: 0.5031 - val_loss: 1.5591 - val_average_precision: 0.5786 - learning_rate: 1.0000e-04
# Epoch 14/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5286 - loss: 1.4280
# Epoch 14: val_average_precision = 0.6031
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 35s 281ms/step - accuracy: 0.5286 - loss: 1.4280 - val_accuracy: 0.5386 - val_loss: 1.4949 - val_average_precision: 0.6031 - learning_rate: 1.0000e-04
# Epoch 15/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5812 - loss: 1.3732
# Epoch 15: val_average_precision = 0.6115
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 37s 301ms/step - accuracy: 0.5812 - loss: 1.3731 - val_accuracy: 0.5491 - val_loss: 1.4417 - val_average_precision: 0.6115 - learning_rate: 1.0000e-04
# Epoch 16/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5990 - loss: 1.2627
# Epoch 16: val_average_precision = 0.6230
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 38s 304ms/step - accuracy: 0.5989 - loss: 1.2630 - val_accuracy: 0.5678 - val_loss: 1.4164 - val_average_precision: 0.6230 - learning_rate: 1.0000e-04
# Epoch 17/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6191 - loss: 1.2146
# Epoch 17: val_average_precision = 0.6178
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 36s 293ms/step - accuracy: 0.6190 - loss: 1.2148 - val_accuracy: 0.5491 - val_loss: 1.4198 - val_average_precision: 0.6178 - learning_rate: 1.0000e-04
# Epoch 18/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6349 - loss: 1.1911
# Epoch 18: val_average_precision = 0.6307
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.6348 - loss: 1.1912 - val_accuracy: 0.5678 - val_loss: 1.3900 - val_average_precision: 0.6307 - learning_rate: 1.0000e-04
# Epoch 19/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6317 - loss: 1.1622
# Epoch 19: val_average_precision = 0.6376
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.6317 - loss: 1.1622 - val_accuracy: 0.5825 - val_loss: 1.3702 - val_average_precision: 0.6376 - learning_rate: 1.0000e-04
# Epoch 20/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6291 - loss: 1.1320
# Epoch 20: val_average_precision = 0.6420
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 38s 311ms/step - accuracy: 0.6291 - loss: 1.1321 - val_accuracy: 0.5783 - val_loss: 1.3419 - val_average_precision: 0.6420 - learning_rate: 1.0000e-04
# Epoch 21/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6514 - loss: 1.1238
# Epoch 21: val_average_precision = 0.6438
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 315ms/step - accuracy: 0.6514 - loss: 1.1235 - val_accuracy: 0.5783 - val_loss: 1.3366 - val_average_precision: 0.6438 - learning_rate: 1.0000e-04
# Epoch 22/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.6707 - loss: 1.0633
# Epoch 22: val_average_precision = 0.6421
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 314ms/step - accuracy: 0.6707 - loss: 1.0632 - val_accuracy: 0.5866 - val_loss: 1.3224 - val_average_precision: 0.6421 - learning_rate: 1.0000e-04
# Epoch 23/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.6841 - loss: 1.0157
# Epoch 23: val_average_precision = 0.6439
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 312ms/step - accuracy: 0.6840 - loss: 1.0159 - val_accuracy: 0.5720 - val_loss: 1.3283 - val_average_precision: 0.6439 - learning_rate: 1.0000e-04
# Epoch 24/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6993 - loss: 0.9922
# Epoch 24: val_average_precision = 0.6512
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 314ms/step - accuracy: 0.6992 - loss: 0.9922 - val_accuracy: 0.5595 - val_loss: 1.3155 - val_average_precision: 0.6512 - learning_rate: 1.0000e-04
# Epoch 25/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.6956 - loss: 0.9528
# Epoch 25: val_average_precision = 0.6531
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 316ms/step - accuracy: 0.6956 - loss: 0.9528 - val_accuracy: 0.5908 - val_loss: 1.2973 - val_average_precision: 0.6531 - learning_rate: 1.0000e-04
# Epoch 26/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6977 - loss: 0.9799
# Epoch 26: val_average_precision = 0.6600
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 348ms/step - accuracy: 0.6978 - loss: 0.9798 - val_accuracy: 0.5825 - val_loss: 1.2855 - val_average_precision: 0.6600 - learning_rate: 1.0000e-04
# Epoch 27/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7177 - loss: 0.8836
# Epoch 27: val_average_precision = 0.6623
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 50s 398ms/step - accuracy: 0.7177 - loss: 0.8839 - val_accuracy: 0.5929 - val_loss: 1.2798 - val_average_precision: 0.6623 - learning_rate: 1.0000e-04
# Epoch 28/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7106 - loss: 0.8956
# Epoch 28: val_average_precision = 0.6680
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 47s 379ms/step - accuracy: 0.7106 - loss: 0.8955 - val_accuracy: 0.6013 - val_loss: 1.2697 - val_average_precision: 0.6680 - learning_rate: 1.0000e-04
# Epoch 29/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7303 - loss: 0.8669
# Epoch 29: val_average_precision = 0.6647
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 44s 355ms/step - accuracy: 0.7302 - loss: 0.8670 - val_accuracy: 0.6013 - val_loss: 1.2782 - val_average_precision: 0.6647 - learning_rate: 1.0000e-04
# Epoch 30/30
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7491 - loss: 0.8326
# Epoch 30: val_average_precision = 0.6729
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 318ms/step - accuracy: 0.7490 - loss: 0.8326 - val_accuracy: 0.5971 - val_loss: 1.2746 - val_average_precision: 0.6729 - learning_rate: 1.0000e-04

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')
plt.show()

# %%
#model.save('../models/my_model_epochs20.h5')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import image

from os import listdir
from os.path import isfile, join

import tensorflow as tf

from tensorflow.keras import callbacks, Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, GlobalAveragePooling2D
from keras.applications import MobileNet, EfficientNetB3
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import average_precision_score
# Out:
# 2025-10-21 20:00:31.077879: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 20:00:31.087377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761069631.099822  154447 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761069631.103984  154447 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-21 20:00:31.116239: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Note: Use conda tf-gpu environment

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
spec_dir = '../data/image_data/'
sample_dir = '../data/image_data/Polistes_dominula/'

paths_sample_plot = [join(sample_dir, f) for f in listdir(sample_dir) if isfile(join(sample_dir, f))]

# %% [markdown]
# - (b) View Batch

# %%
plt.figure(figsize=(6,6))

plt.subplot(221)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(222)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(223)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(224)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]));

# %% [markdown]
# Define Batch size

# %%
batch_size = 32

# %% [markdown]
# ## B - <a name="generateurs"></a> Data Generators

# %%
data_generator = ImageDataGenerator(rescale = 1./255,
                                    validation_split = 0.2,
                                    rotation_range=20,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    brightness_range=(0.8, 1.2),
                                    fill_mode='nearest'
                                   )

# %% [markdown]
# - (d) Implement ```training_data```, ```valid_data``` splits

# %%
training_data  = data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "training", 
                                                   batch_size = batch_size)

validation_data  = data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "validation", 
                                                   batch_size = batch_size)
# Out:
# Found 10989 images belonging to 127 classes.
# Found 2726 images belonging to 127 classes.

# %% [markdown]
# # II - <a name="classif"></a> Classification

# %%
# Model MobileNet
base_model = MobileNet(weights='imagenet', include_top=False)

# Freezer les couches
#for layer in base_model.layers:
#    layer.trainable = False


"""
# Unfreeze the last N trainable convolutional blocks
trainable = False
for layer in reversed(base_model.layers):
    if 'conv' in layer.name:
        if N == 0:
            break
        N -= 1
        trainable = True
    layer.trainable = trainable
"""

model = Sequential()
model.add(base_model) # Ajout du modèl
model.add(GlobalAveragePooling2D())
model.add(Dropout(rate=0.3))
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(127, activation='softmax'))
# Out:
# /tmp/ipykernel_154447/3838958738.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(weights='imagenet', include_top=False)
# I0000 00:00:1761069634.896355  154447 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 47179 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:65:00.0, compute capability: 7.5
# I0000 00:00:1761069634.897429  154447 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46919 MB memory:  -> device: 1, name: Quadro RTX 8000, pci bus id: 0000:b6:00.0, compute capability: 7.5

# %%
early_stopping = callbacks.EarlyStopping(monitor = 'val_loss',
                                         patience = 12,
                                         mode = 'min',
                                         restore_best_weights = True)

lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                        patience=4,
                                         factor=0.5,
                                         verbose=2,
                                         mode='max',
                                         min_lr = 1e-10)

# %%
optimizer = Adam(learning_rate=0.0001)

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import average_precision_score
from sklearn.preprocessing import label_binarize

class AveragePrecisionCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_generator, num_classes=127):
        super().__init__()
        self.val_generator = val_generator
        self.num_classes = num_classes

    def on_epoch_end(self, epoch, logs=None):
        y_true = []
        y_pred = []

        for i in range(len(self.val_generator)):
            x_batch, y_batch = self.val_generator[i]  # y_batch: shape (batch_size,)
            preds = self.model.predict(x_batch, verbose=0)  # preds: shape (batch_size, num_classes)

            y_true.extend(y_batch)
            y_pred.extend(preds)

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)

        # One-hot encode y_true to match y_pred's shape
        y_true_onehot = label_binarize(y_true, classes=range(self.num_classes))

        # Compute average precision per class
        aps = []
        for i in range(self.num_classes):
            ap = average_precision_score(y_true_onehot[:, i], y_pred[:, i])
            aps.append(ap)

        macro_ap = np.mean(aps)
        print(f"\nEpoch {epoch + 1}: val_average_precision = {macro_ap:.4f}")
        logs = logs or {}
        logs['val_average_precision'] = macro_ap

# %%
ap_callback = AveragePrecisionCallback(val_generator=validation_data)

# %%
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(training_data, validation_data=validation_data, epochs=30, 
                    callbacks=[ap_callback,lr_plateau, early_stopping])
# Out:
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# I0000 00:00:1761069644.606072  154917 service.cc:148] XLA service 0x78d820019430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761069644.606109  154917 service.cc:156]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# I0000 00:00:1761069644.606116  154917 service.cc:156]   StreamExecutor device (1): Quadro RTX 8000, Compute Capability 7.5
# 2025-10-21 20:00:44.857012: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1761069645.708087  154917 cuda_dnn.cc:529] Loaded cuDNN version 91200
# E0000 00:00:1761069647.372445  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069647.498432  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069650.184683  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069650.306737  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069652.343833  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069652.499136  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069652.749822  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069652.876004  154917 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1761069658.205553  154917 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 110/344 ━━━━━━━━━━━━━━━━━━━━ 1:25 365ms/step - accuracy: 0.0237 - loss: 4.9706
# E0000 00:00:1761069701.232123  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069701.356706  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069703.936838  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069704.085444  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069704.208884  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069705.872465  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069705.997833  154916 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.0611 - loss: 4.6041
# E0000 00:00:1761069830.008351  154919 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069830.136945  154919 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069832.595377  154919 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761069832.739652  154919 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_average_precision = 0.2644
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 237s 625ms/step - accuracy: 0.1216 - loss: 4.1226 - val_accuracy: 0.2542 - val_loss: 3.1591 - val_average_precision: 0.2644 - learning_rate: 1.0000e-04
# Epoch 2/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3278 - loss: 2.8222
# Epoch 2: val_average_precision = 0.4119
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 195s 567ms/step - accuracy: 0.3555 - loss: 2.6295 - val_accuracy: 0.3885 - val_loss: 2.3844 - val_average_precision: 0.4119 - learning_rate: 1.0000e-04
# Epoch 3/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.4661 - loss: 2.0403
# Epoch 3: val_average_precision = 0.4909
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 193s 562ms/step - accuracy: 0.4776 - loss: 1.9833 - val_accuracy: 0.4622 - val_loss: 2.0272 - val_average_precision: 0.4909 - learning_rate: 1.0000e-04
# Epoch 4/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.5530 - loss: 1.6540
# Epoch 4: val_average_precision = 0.5063
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 194s 563ms/step - accuracy: 0.5540 - loss: 1.6394 - val_accuracy: 0.4773 - val_loss: 1.9345 - val_average_precision: 0.5063 - learning_rate: 1.0000e-04
# Epoch 5/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.6166 - loss: 1.3930
# Epoch 5: val_average_precision = 0.5477
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 195s 566ms/step - accuracy: 0.6084 - loss: 1.4073 - val_accuracy: 0.5301 - val_loss: 1.8065 - val_average_precision: 0.5477 - learning_rate: 1.0000e-04
# Epoch 6/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.6580 - loss: 1.2032
# Epoch 6: val_average_precision = 0.5481
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 195s 566ms/step - accuracy: 0.6547 - loss: 1.2133 - val_accuracy: 0.5161 - val_loss: 1.8176 - val_average_precision: 0.5481 - learning_rate: 1.0000e-04
# Epoch 7/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7081 - loss: 1.0191
# Epoch 7: val_average_precision = 0.5611
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 192s 557ms/step - accuracy: 0.6974 - loss: 1.0546 - val_accuracy: 0.5367 - val_loss: 1.7273 - val_average_precision: 0.5611 - learning_rate: 1.0000e-04
# Epoch 8/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.7243 - loss: 0.9142
# Epoch 8: val_average_precision = 0.5709
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 195s 566ms/step - accuracy: 0.7177 - loss: 0.9346 - val_accuracy: 0.5312 - val_loss: 1.7926 - val_average_precision: 0.5709 - learning_rate: 1.0000e-04
# Epoch 9/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.7595 - loss: 0.8082
# Epoch 9: val_average_precision = 0.5708
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 191s 556ms/step - accuracy: 0.7565 - loss: 0.8228 - val_accuracy: 0.5348 - val_loss: 1.8294 - val_average_precision: 0.5708 - learning_rate: 1.0000e-04
# Epoch 10/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7969 - loss: 0.6844
# Epoch 10: val_average_precision = 0.5767
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 190s 552ms/step - accuracy: 0.7872 - loss: 0.7170 - val_accuracy: 0.5543 - val_loss: 1.7558 - val_average_precision: 0.5767 - learning_rate: 1.0000e-04
# Epoch 11/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8209 - loss: 0.6064
# Epoch 11: val_average_precision = 0.5876
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 193s 560ms/step - accuracy: 0.8049 - loss: 0.6472 - val_accuracy: 0.5444 - val_loss: 1.8068 - val_average_precision: 0.5876 - learning_rate: 1.0000e-04
# Epoch 12/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8314 - loss: 0.5656
# Epoch 12: val_average_precision = 0.5819
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 194s 565ms/step - accuracy: 0.8296 - loss: 0.5687 - val_accuracy: 0.5631 - val_loss: 1.7995 - val_average_precision: 0.5819 - learning_rate: 1.0000e-04
# Epoch 13/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8568 - loss: 0.4742
# Epoch 13: val_average_precision = 0.5828
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 192s 559ms/step - accuracy: 0.8461 - loss: 0.5059 - val_accuracy: 0.5664 - val_loss: 1.7658 - val_average_precision: 0.5828 - learning_rate: 1.0000e-04
# Epoch 14/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8686 - loss: 0.4281
# Epoch 14: val_average_precision = 0.5787
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 192s 559ms/step - accuracy: 0.8584 - loss: 0.4538 - val_accuracy: 0.5635 - val_loss: 1.8621 - val_average_precision: 0.5787 - learning_rate: 1.0000e-04
# Epoch 15/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8808 - loss: 0.3961
# Epoch 15: val_average_precision = 0.5840
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 193s 561ms/step - accuracy: 0.8779 - loss: 0.4061 - val_accuracy: 0.5506 - val_loss: 1.8876 - val_average_precision: 0.5840 - learning_rate: 1.0000e-04
# Epoch 16/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8961 - loss: 0.3511
# Epoch 16: val_average_precision = 0.5766
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 193s 561ms/step - accuracy: 0.8917 - loss: 0.3595 - val_accuracy: 0.5433 - val_loss: 1.9556 - val_average_precision: 0.5766 - learning_rate: 1.0000e-04
# Epoch 17/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9045 - loss: 0.3203
# Epoch 17: val_average_precision = 0.5812
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 193s 561ms/step - accuracy: 0.8977 - loss: 0.3356 - val_accuracy: 0.5598 - val_loss: 1.9468 - val_average_precision: 0.5812 - learning_rate: 1.0000e-04
# Epoch 18/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9209 - loss: 0.2596
# Epoch 18: val_average_precision = 0.5994
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 192s 559ms/step - accuracy: 0.9266 - loss: 0.2519 - val_accuracy: 0.5836 - val_loss: 1.7469 - val_average_precision: 0.5994 - learning_rate: 5.0000e-05
# Epoch 19/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9409 - loss: 0.2097
# Epoch 19: val_average_precision = 0.6043
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 194s 565ms/step - accuracy: 0.9367 - loss: 0.2172 - val_accuracy: 0.5888 - val_loss: 1.7813 - val_average_precision: 0.6043 - learning_rate: 5.0000e-05
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')
plt.show()

# %%
model.save('../models/model_127_species_exp4.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

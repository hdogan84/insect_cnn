# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import image

from os import listdir
from os.path import isfile, join

import tensorflow as tf

from tensorflow.keras import callbacks, Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, GlobalAveragePooling2D
from keras.applications import MobileNet, EfficientNetB3
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import average_precision_score
# Out:
# 2025-10-21 19:02:06.422942: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 19:02:06.469753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761066126.484787    9478 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761066126.490637    9478 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-21 19:02:06.549153: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Note: Use conda tf-gpu environment

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
spec_dir = '../data/image_data/'
sample_dir = '../data/image_data/Polistes_dominula/'

paths_sample_plot = [join(sample_dir, f) for f in listdir(sample_dir) if isfile(join(sample_dir, f))]

# %% [markdown]
# - (b) View Batch

# %%
plt.figure(figsize=(6,6))

plt.subplot(221)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(222)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(223)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]))

plt.subplot(224)
plt.axis('off')
plt.imshow(image.imread(paths_sample_plot[np.random.randint(len(paths_sample_plot))]));

# %% [markdown]
# Define Batch size

# %%
batch_size = 32

# %% [markdown]
# ## B - <a name="generateurs"></a> Data Generators

# %%
seed = 42
train_data_generator = ImageDataGenerator(rescale = 1./255,
                                    validation_split = 0.2,
                                    rotation_range=20,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    brightness_range=(0.8, 1.2),
                                    fill_mode='nearest',
                                   )

val_data_generator = ImageDataGenerator(rescale = 1./255,
                                    validation_split = 0.2,
                                   )

# %% [markdown]
# - (d) Implement ```training_data```, ```valid_data``` splits

# %%
training_data  = train_data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "training", 
                                                   batch_size = batch_size)

validation_data  = val_data_generator.flow_from_directory(directory = spec_dir,
                                                   target_size = (224, 224),
                                                   class_mode = 'binary',
                                                   subset = "validation", 
                                                   batch_size = batch_size)
# Out:
# Found 10989 images belonging to 127 classes.
# Found 2726 images belonging to 127 classes.

# %% [markdown]
# # II - <a name="classif"></a> Classification

# %%
# Model MobileNet
base_model = MobileNet(weights='imagenet', include_top=False)

# Freezer les couches
#for layer in base_model.layers:
#    layer.trainable = False


"""
# Unfreeze the last N trainable convolutional blocks
trainable = False
for layer in reversed(base_model.layers):
    if 'conv' in layer.name:
        if N == 0:
            break
        N -= 1
        trainable = True
    layer.trainable = trainable
"""

model = Sequential()
model.add(base_model) # Ajout du modèl
model.add(GlobalAveragePooling2D())
model.add(Dropout(rate=0.3))
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(127, activation='softmax'))
# Out:
# /tmp/ipykernel_9478/3838958738.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(weights='imagenet', include_top=False)
# I0000 00:00:1761066130.777954    9478 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 47179 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:65:00.0, compute capability: 7.5
# I0000 00:00:1761066130.779195    9478 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46919 MB memory:  -> device: 1, name: Quadro RTX 8000, pci bus id: 0000:b6:00.0, compute capability: 7.5

# %%
early_stopping = callbacks.EarlyStopping(monitor = 'val_loss',
                                         patience = 12,
                                         mode = 'min',
                                         restore_best_weights = True)

lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                        patience=4,
                                         factor=0.5,
                                         verbose=2,
                                         mode='max',
                                         min_lr = 1e-10)

# %%
optimizer = Adam(learning_rate=0.0001)

# %%
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import average_precision_score
from sklearn.preprocessing import label_binarize

class AveragePrecisionCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_generator, num_classes=127):
        super().__init__()
        self.val_generator = val_generator
        self.num_classes = num_classes

    def on_epoch_end(self, epoch, logs=None):
        y_true = []
        y_pred = []

        for i in range(len(self.val_generator)):
            x_batch, y_batch = self.val_generator[i]  # y_batch: shape (batch_size,)
            preds = self.model.predict(x_batch, verbose=0)  # preds: shape (batch_size, num_classes)

            y_true.extend(y_batch)
            y_pred.extend(preds)

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)

        # One-hot encode y_true to match y_pred's shape
        y_true_onehot = label_binarize(y_true, classes=range(self.num_classes))

        # Compute average precision per class
        aps = []
        for i in range(self.num_classes):
            ap = average_precision_score(y_true_onehot[:, i], y_pred[:, i])
            aps.append(ap)

        macro_ap = np.mean(aps)
        print(f"\nEpoch {epoch + 1}: val_average_precision = {macro_ap:.4f}")
        logs = logs or {}
        logs['val_average_precision'] = macro_ap

# %%
ap_callback = AveragePrecisionCallback(val_generator=validation_data)

# %%
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(training_data, validation_data=validation_data, epochs=30, 
                    callbacks=[ap_callback,lr_plateau, early_stopping])
# Out:
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# I0000 00:00:1761066140.814688    9800 service.cc:148] XLA service 0x7dac20004ee0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761066140.814710    9800 service.cc:156]   StreamExecutor device (0): Quadro RTX 8000, Compute Capability 7.5
# I0000 00:00:1761066140.814712    9800 service.cc:156]   StreamExecutor device (1): Quadro RTX 8000, Compute Capability 7.5
# 2025-10-21 19:02:21.051403: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1761066141.996699    9800 cuda_dnn.cc:529] Loaded cuDNN version 91200
# E0000 00:00:1761066143.753652    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066143.877092    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066146.677270    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066146.822685    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066146.943105    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066148.983161    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066149.137221    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066149.400962    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066149.526340    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1761066155.198415    9800 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  37/344 ━━━━━━━━━━━━━━━━━━━━ 1:53 371ms/step - accuracy: 0.0132 - loss: 5.1658
# E0000 00:00:1761066171.771823    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066171.895429    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066174.448922    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066174.570376    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066176.223613    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066176.347303    9801 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.0727 - loss: 4.5422
# E0000 00:00:1761066312.155372    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066312.278423    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066314.715085    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761066314.836911    9800 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_average_precision = 0.2894
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 204s 529ms/step - accuracy: 0.1336 - loss: 4.0370 - val_accuracy: 0.2986 - val_loss: 3.0281 - val_average_precision: 0.2894 - learning_rate: 1.0000e-04
# Epoch 2/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.3315 - loss: 2.7724
# Epoch 2: val_average_precision = 0.4263
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 157s 456ms/step - accuracy: 0.3603 - loss: 2.6007 - val_accuracy: 0.4079 - val_loss: 2.3190 - val_average_precision: 0.4263 - learning_rate: 1.0000e-04
# Epoch 3/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.4687 - loss: 2.0306
# Epoch 3: val_average_precision = 0.4692
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 155s 450ms/step - accuracy: 0.4756 - loss: 1.9784 - val_accuracy: 0.4413 - val_loss: 2.1574 - val_average_precision: 0.4692 - learning_rate: 1.0000e-04
# Epoch 4/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.5610 - loss: 1.6197
# Epoch 4: val_average_precision = 0.5137
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 453ms/step - accuracy: 0.5520 - loss: 1.6339 - val_accuracy: 0.4868 - val_loss: 1.9835 - val_average_precision: 0.5137 - learning_rate: 1.0000e-04
# Epoch 5/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.6134 - loss: 1.3852
# Epoch 5: val_average_precision = 0.5452
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 157s 455ms/step - accuracy: 0.6067 - loss: 1.4047 - val_accuracy: 0.5202 - val_loss: 1.8376 - val_average_precision: 0.5452 - learning_rate: 1.0000e-04
# Epoch 6/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.6606 - loss: 1.1879
# Epoch 6: val_average_precision = 0.5564
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 157s 456ms/step - accuracy: 0.6547 - loss: 1.2012 - val_accuracy: 0.5231 - val_loss: 1.8462 - val_average_precision: 0.5564 - learning_rate: 1.0000e-04
# Epoch 7/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7008 - loss: 1.0231
# Epoch 7: val_average_precision = 0.5550
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 154s 447ms/step - accuracy: 0.6916 - loss: 1.0533 - val_accuracy: 0.5345 - val_loss: 1.8615 - val_average_precision: 0.5550 - learning_rate: 1.0000e-04
# Epoch 8/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7251 - loss: 0.9109
# Epoch 8: val_average_precision = 0.5671
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 157s 456ms/step - accuracy: 0.7207 - loss: 0.9232 - val_accuracy: 0.5282 - val_loss: 1.8607 - val_average_precision: 0.5671 - learning_rate: 1.0000e-04
# Epoch 9/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.7617 - loss: 0.8112
# Epoch 9: val_average_precision = 0.5751
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 453ms/step - accuracy: 0.7596 - loss: 0.8163 - val_accuracy: 0.5459 - val_loss: 1.7876 - val_average_precision: 0.5751 - learning_rate: 1.0000e-04
# Epoch 10/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.7813 - loss: 0.7217
# Epoch 10: val_average_precision = 0.5738
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 155s 452ms/step - accuracy: 0.7774 - loss: 0.7309 - val_accuracy: 0.5459 - val_loss: 1.8366 - val_average_precision: 0.5738 - learning_rate: 1.0000e-04
# Epoch 11/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8156 - loss: 0.6307
# Epoch 11: val_average_precision = 0.5804
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 154s 447ms/step - accuracy: 0.8064 - loss: 0.6576 - val_accuracy: 0.5481 - val_loss: 1.9737 - val_average_precision: 0.5804 - learning_rate: 1.0000e-04
# Epoch 12/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8322 - loss: 0.5487
# Epoch 12: val_average_precision = 0.5861
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 157s 457ms/step - accuracy: 0.8341 - loss: 0.5578 - val_accuracy: 0.5525 - val_loss: 1.8294 - val_average_precision: 0.5861 - learning_rate: 1.0000e-04
# Epoch 13/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8587 - loss: 0.4825
# Epoch 13: val_average_precision = 0.5863
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 453ms/step - accuracy: 0.8430 - loss: 0.5214 - val_accuracy: 0.5503 - val_loss: 1.8323 - val_average_precision: 0.5863 - learning_rate: 1.0000e-04
# Epoch 14/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8708 - loss: 0.4372
# Epoch 14: val_average_precision = 0.5782
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 453ms/step - accuracy: 0.8617 - loss: 0.4605 - val_accuracy: 0.5466 - val_loss: 1.9772 - val_average_precision: 0.5782 - learning_rate: 1.0000e-04
# Epoch 15/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8830 - loss: 0.3933
# Epoch 15: val_average_precision = 0.5752
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 453ms/step - accuracy: 0.8723 - loss: 0.4215 - val_accuracy: 0.5583 - val_loss: 2.0380 - val_average_precision: 0.5752 - learning_rate: 1.0000e-04
# Epoch 16/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8967 - loss: 0.3513
# Epoch 16: val_average_precision = 0.5819
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 452ms/step - accuracy: 0.8890 - loss: 0.3674 - val_accuracy: 0.5561 - val_loss: 2.0348 - val_average_precision: 0.5819 - learning_rate: 1.0000e-04
# Epoch 17/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9045 - loss: 0.3265
# Epoch 17: val_average_precision = 0.5831
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 156s 454ms/step - accuracy: 0.8985 - loss: 0.3409 - val_accuracy: 0.5569 - val_loss: 1.9677 - val_average_precision: 0.5831 - learning_rate: 1.0000e-04
# Epoch 18/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9071 - loss: 0.3101
# Epoch 18: val_average_precision = 0.5816
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 155s 452ms/step - accuracy: 0.9024 - loss: 0.3245 - val_accuracy: 0.5602 - val_loss: 1.9857 - val_average_precision: 0.5816 - learning_rate: 1.0000e-04
# Epoch 19/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9177 - loss: 0.2759
# Epoch 19: val_average_precision = 0.5737
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 155s 451ms/step - accuracy: 0.9077 - loss: 0.2964 - val_accuracy: 0.5433 - val_loss: 2.1091 - val_average_precision: 0.5737 - learning_rate: 1.0000e-04
# Epoch 20/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9142 - loss: 0.2740
# Epoch 20: val_average_precision = 0.5665
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 154s 447ms/step - accuracy: 0.9134 - loss: 0.2773 - val_accuracy: 0.5433 - val_loss: 2.2264 - val_average_precision: 0.5665 - learning_rate: 1.0000e-04
# Epoch 21/30
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9277 - loss: 0.2380
# Epoch 21: val_average_precision = 0.5682
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 154s 447ms/step - accuracy: 0.9200 - loss: 0.2589 - val_accuracy: 0.5462 - val_loss: 2.2638 - val_average_precision: 0.5682 - learning_rate: 1.0000e-04
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/hakandogan/.conda/envs/tf-gpu/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='right')
plt.show()

# %%
model.save('../models/model_127_species_exp5.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

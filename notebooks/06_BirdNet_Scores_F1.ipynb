# %% [markdown]
# ###Env to use: birdnet

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import numpy as np

dataset1_score = np.load('dataset1_f1.npz')
dataset2_score = np.load('holderried_f1.npz')

# %%
thr1 = dataset1_score["thr"]
f1_ds1 = dataset1_score["f1"]

thr2 = dataset2_score["thr"]
f1_ds2 = dataset2_score["f1"]

# %%
plt.plot(thr1, f1_ds1, color='blue', linestyle='-', label='Dataset 1')  # Solid blue line
plt.plot(thr2, f1_ds2, color='red', linestyle='--', label='Dataset 2')   # Dashed red line

plt.xlabel('Confidence threshold')
plt.ylabel(r'$\mathrm{F}_1$ score')
plt.title('Comparison of Two Datasets')
plt.legend()
plt.ylim([0,1.01])
plt.grid(True)
plt.show()

# %%
np.max(f1_ds1)
# Out:
# 0.8149152313737259

# %%
np.max(f1_ds2)
# Out:
# 0.8332588911997065

# %%
f1_ds1[50]
# Out:
# 0.8036852487809907

# %%
f1_ds2[50]
# Out:
# 0.7137032363390668
